# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
arr_number = np.arange(-20.0, 20.0, 0.2) # create a random number
soft_maxNum=np.exp(arr_number)/np.sum(np.exp(arr_number)) # logic of softmax e^=2.7*x
plt.plot(arr_number,soft_maxNum)

# %%
def SoftmaxActivationFunction(number):
    store=[]
    for i in number:
        soft_maxNum=np.exp(arr_number)/np.sum(np.exp(arr_number))
        store.append(soft_maxNum)
    return store

# %%
arr_number2 = np.arange(-20.0, 20.0, 0.2)
soft=SoftmaxActivationFunction(arr_number2)
plt.plot(arr_number2,soft)
ax=plt.gca()
plt.show()

# %%
np.random.randn(10)
# Out:
# array([ 0.52042201, -1.69685294, -0.33918767, -0.06836569,  0.30582786,
#        -0.66953469, -1.78024916,  0.74440556,  0.35116947,  1.80127056])

# %%
arr_number1 = np.random.randn(10) # create a random number
soft_maxNum=np.exp(arr_number)/np.sum(np.exp(arr_number)) # logic of softmax e^=2.7*x
plt.plot(arr_number,soft_maxNum)
